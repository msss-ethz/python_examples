# %% [markdown]
# <a href="https://colab.research.google.com/github/msss-ethz/python_examples/blob/master/src/2DCellularAutomata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modeling and Simulating Social Systems - <font size=4 color='gray'>Leonel Aguilar 2018</font>
# # <font color='gray'>Lecture 7 - 2D Cellular Automata</font>

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np #matrix and vector library
import matplotlib.pyplot as plt #plotting library
from random import shuffle

# %% [markdown]
# ### Define plots to be inlined

# %%
#Jupyter magic that makes plots to be inlined in the notebook
# %matplotlib inline

# %% [markdown]
# ### Create cell

# %%
#Dimensions of the 2D cells space
x_dim=10 
y_dim=10
cells = np.zeros([x_dim,y_dim]) #creating empty cells
cells[0][0]=1
#cells[int(x_dim*0.8),int(x_dim*0.8)]=1 #Adding seed
#cells[int(x_dim*0.2),int(x_dim*0.2)]=1 #Adding another seed

# %% [markdown]
# ## Create a function to plot the 2D grid of cells

# %%
def Plot2DAutomata(cellHistory,ax=None):
    """
    """
    #create a new plot if no ax was given
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(16, 16)) #Determine the number of subplots in the figure and its size
    
    #Replace values to get a specific color
    minVal=0
    maxVal=2
    
    cmap = plt.cm.gray
    norm = plt.Normalize(minVal,maxVal)
    rgba = cmap(norm(cellHistory))

    S = np.argwhere(cellHistory==0)
    I = np.argwhere(cellHistory==1)
    R = np.argwhere(cellHistory==2)
    
    red=[1,0,0]
    green=[0,1,0]
    blue=[0,0,1]
    
    for position,color in zip([S,I,R],[red,green,blue]):
        for pos in position:
            rgba[pos[0]][pos[1],:3]=color
    
    #plot the matrix
    ax.imshow(rgba,origin='lower', interpolation='none') #Type of plot 
    
    #Axis labels
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    
    
    #Major ticks frequency
    mTickNum=1
    xNum=1 #int(cellHistory.shape[0]/mTickNum)
    yNum=1 #int(cellHistory.shape[1]/mTickNum)+1
         
    #Major ticks
    ax.set_xticks(np.arange(0, cellHistory.shape[0], xNum))
    ax.set_yticks(np.arange(0, cellHistory.shape[1], yNum))
    
    #Major tick labels
    ax.set_xticklabels(np.arange(0, cellHistory.shape[0]+1, xNum))
    ax.set_yticklabels(np.arange(0, cellHistory.shape[1]+1, yNum))
    
    # Minor ticks
    ax.set_xticks(np.arange(-.5, cellHistory.shape[0], 1), minor=True);
    ax.set_yticks(np.arange(-.5, cellHistory.shape[1], 1), minor=True)
    

    
    #Add grid
    #Gray line separating cells
    ax.grid(which='minor', axis='x', color='gray', linestyle='-', linewidth=2)
    ax.grid(which='minor', axis='y', color='gray', linestyle='-', linewidth=2)
    #ax.set_axis_off()

# %% [markdown]
# ### Plot initial state

# %%
Plot2DAutomata(cells)
#cells.shape

# %% [markdown]
# ### Define a function that applies the rule

# %%
def apply_rule(C,neighbourhood):   
    #Assumed Kermack-McKendrick SIR model
    rval=C
    beta=0.5
    gamma=0.2
    if C != 2:
        #For every neighbour it interacts with
        for val in neighbourhood:
            #The current cell gets infected with probability beta
            if val == 1:
                sample=np.random.uniform(0,1)
                if beta>sample:
                    rval=1
        #If the current cell is infected
        if C == 1:
            sample=np.random.uniform(0,1)
            #It recovers with probability gamma
            if gamma>sample:
                #print(self._gamma," --- ",sample, " --- ",self._gamma<sample)
                rval=2

    return rval

# %% [markdown]
# ### Define Neighborhood

# %%
def idxToCoordinates(idx,x_dim):
    return [idx%x_dim,idx//x_dim]

def getNeighbourhood(idx,x_dim,y_dim):
    neighb=[]
    coords=idxToCoordinates(idx,x_dim)
    for j in range(-1,2,1):
        for i in range(-1,2,1):
            #Handle boundary conditions
            if coords[0]+i>=0 and coords[0]+i<x_dim and coords[1]+j>=0 and coords[1]+j<y_dim and (j!=0 or i!=0):
                neighb.append([coords[0]+i,coords[1]+j])
    return (coords,neighb)

def getNeighbourhoodValues(idx,grid,x_dim,y_dim):
    mycoords,neighCoords=getNeighbourhood(idx,x_dim,y_dim)
    
    mystate=grid[mycoords[0]][mycoords[1]]
    neighstate=[]
    for neighc in neighCoords:
        neighstate.append(grid[neighc[0]][neighc[1]])
    #print("- Coords ",mycoords," = ",mystate," neigs ",neighstate," = ",neighCoords)
    return mycoords,mystate,neighstate

# %% [markdown]
# ### Define the step Function

# %%
def step(state):
    """Every timestep the state of the new generation of cells is determined by 
    the previous generation neighborhood
    Input: current state of all cells (state)
    Output: next state of all cells (new_state) 
    """
    all_idx = np.arange(0, x_dim*y_dim, 1)
    shuffle(all_idx)
    new_state = np.zeros([x_dim,y_dim])
    #Iterate through all cells (C) in the automata and extract its neighbourhood
    for idx in all_idx:
        #print("cell ",mycoords)
        mycoords,mystate,neighstate = getNeighbourhoodValues(idx,state,x_dim,y_dim)
        #print("cell ",idx," - ",mycoords)
        new_state[mycoords[0]][mycoords[1]] = apply_rule(mystate,neighstate)
    return new_state

# %% [markdown]
# ### Define the simulation

# %%
def simulation(X,max_steps):
    """Traces the whole evolution of an initial state X through max_steps generations
    Input: X, initial state
    Output: cells_stack.transpose(), matrix stacking the cells state after each timestep 
    """
    cells_stack=[X]
    new_state=X
    #            #print(coords[0]+i," - ",coords[1]+j)Move one step forward max_step times
    for i in range(max_steps):
        #Moves one step forward
        new_state=step(new_state)
        #Stores the result
        cells_stack.append(new_state)
    return cells_stack

# %% [markdown]
# # Performing the simulation
# ___

# %%
max_steps=30 #Number of timesteps
results=simulation(cells,max_steps) #Perform simulation and store its results

# %% [markdown]
# ## Plot results

# %%
Plot2DAutomata(results[-1])

# %%
### Visualize Results

import matplotlib.animation
plt.rcParams["animation.html"] = "jshtml"
from copy import deepcopy
import pandas as pd

# %%
# %%capture
# Build plot
fig, ax = plt.subplots(figsize=(6,4))
resultsCopy= deepcopy(results)

def animate(j):
    ax.clear()
    Plot2DAutomata(results[j],ax=ax)
    
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(results))

# %%
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img06c50c27361148b88b56f510e110c850">
#     <br>
#     <input id="_anim_slider06c50c27361148b88b56f510e110c850" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim06c50c27361148b88b56f510e110c850.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim06c50c27361148b88b56f510e110c850.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select06c50c27361148b88b56f510e110c850" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img06c50c27361148b88b56f510e110c850";
#     var slider_id = "_anim_slider06c50c27361148b88b56f510e110c850";
#     var loop_select_id = "_anim_loop_select06c50c27361148b88b56f510e110c850";
#     var frames = new Array(31);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAFwpJREFUeJzt3X9s1PXhx/HXSWHLyS+ZFPhQflgh\
# cFyF0hbKFoPIUmAMSKDFUDBzUnaN2R8zxsRsMeG6LJOwGEHhj51Z0ElC/1gw8EEgCmzrUjDdx4IZ\
# 0zCiEOmPCDIY0KPX9vh8/xhj331xP767z93n/S7PR0IK9Hz5Shrv5ftzn14jvu/7AgDAMveFXQAA\
# gP8GAwYAsBIDBgCwEgMGALASAwYAsBIDBgCwEgMGALASAwYAsBIDBgCwEgMGALASAwYAsBIDBgCw\
# EgMGALASAwYAsBIDBgCwEgMGALASAwYAsBIDBgCwEgMGALASAwYAsBIDBgCwEgMGALASAwYAsBID\
# BgCwEgMGALASAwYAsBIDBgCwEgMGALASAwYAsBIDBgCwEgMGALASAwYAsBIDBgCwEgMGALBSUdgF\
# 8N9zXVeu6+rNN9/U1772tbDrAINWX3e3vvD9sGvg/4j4Pl8V2zmOo67u7sDympJJSdLm2x/JDS7X\
# pq625eazq5tMyuOp0jhcQgQAWIkBAwBYiQEDAFiJAQMAWIkBM9D27dtVVlameDyubdu2hV0HAIzE\
# gBnm9OnTev3119XW1qYPP/xQBw4c0NmzZ8OuBQDGYcAM8/HHH2vBggWKRqMqKirSY489prfffjvs\
# WgBgHAbMMGVlZWppadHly5eVTqd18OBBXbhwIexaAGAc3onDMLFYTC+88IJqamo0fPhwzZkzR0VF\
# d3+ZUqmUUqmUJCmdThe6JgCEjhOYgRoaGtTe3q6WlhaNGTNG06dPv+sxiURCnufJ8zxFo9EQWgJA\
# uDiBGejixYsqLi7WZ599pr179+rEiRNhVwIA4zBgBqqtrdXly5c1dOhQ7dy5Uw888EDYlQDAOAyY\
# gX73u9+FXQEAjMdrYAAAKzFgAAArMWAAACsxYAAAKzFgAAArRXyfn5NtO8dx1NjYGHYNYNByk0l5\
# PFUah9voLea6rlzXVSaTCbsKABQcJ7BBwHEcdXV3B5bXlExKkjbf/khucLk2dbUtN59dOYGZidfA\
# AABWYsAAAFZiwAAAVmLAAABWYsAAAFZiwAz0yiuvKB6Pq6ysTPX19ert7Q27EgAYhwEzTGdnp159\
# 9VV5nqfTp08rm82qubk57FoAYBwGzEADAwO6efOmBgYGlE6n5ThO2JUAwDgMmGEmTpyo559/XpMn\
# T9aECRM0atQoLVmyJOxaAGAcBswwV65c0b59+3Tu3Dl1dXWpp6dHu3fvvutxqVRKVVVVqqqqUjqd\
# DqEpAISLATPMkSNH9NBDD2ns2LEaOnSo1qxZo+PHj9/1uEQiIc/z5HmeotFoCE0BIFwMmGEmT56s\
# 999/X+l0Wr7v6+jRo4rFYmHXAgDjMGCGqa6uVl1dnSoqKvTII4/o1q1bSiQSYdcCAOPw41QM1NTU\
# pKamprBrAIDROIEBAKzEgAEArMSAAQCsxIABAKzEgAEArBTxfd8PuwRy4ziOGhsbw64BDFpuMimP\
# p0rjcBu9xVzXleu6ymQyYVcBgILjBDYIOI6jru7uwPKakklJ0ubbH8kNLtemrrbl5rMrJzAz8RoY\
# AMBKDBgAwEoMGADASgwYAMBKDBgAwEoMmGHOnDmj8vLyO79Gjhypbdu2hV0LAIzD94EZZsaMGTp1\
# 6pQkKZvNauLEiVq9enXIrQDAPJzADHb06FE9/PDDmjJlSthVAMA4DJjBmpubVV9fH3YNADASA2ao\
# vr4+7d+/X2vXrv3Sz6dSKVVVVamqqkrpdLrA7QAgfAyYoQ4dOqSKigqNGzfuSz+fSCTkeZ48z1M0\
# Gi1wOwAIHwNmqD179nD5EAD+BQbMQOl0Wu+9957WrFkTdhUAMBa30RsoGo3q8uXL

# %%
# Set up formatting for the movie files
Writer = matplotlib.animation.writers['ffmpeg']
writer = Writer(fps=15, metadata=dict(artist='Leo'), bitrate=1800)
ani.save('2DCA.mp4', writer=writer)

# %%
stacked=[result.flatten() for result in results]

# %%
df = pd.DataFrame(stacked)

# %%
S = df[df==0].count(axis='columns')
I = df[df==1].count(axis='columns')
R = df[df==2].count(axis='columns')

# %%
x = np.arange(0.0, max_steps+1, 1)

# %%
plt.plot(x,S,'red', label='S')
plt.plot(x,I,'green', label='I')
plt.plot(x,R,'blue', label='R')
plt.xlabel('Timstep')
plt.ylabel('Count')
plt.title('Simulation results')
plt.legend(['Suceptible','Infected','Recovered'])
plt.show()
